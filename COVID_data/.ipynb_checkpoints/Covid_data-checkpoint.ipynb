# %% [markdown]
# ### COVID 19 data clean up and plotting

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# import Dependencies
import mpl_toolkits.axisartist as AA
from pylab import figure, show, legend, ylabel
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# Get datafile
allState_path = "us-states.csv"
usCovid_path = "national-history.csv"
conSent_path = "UMICH-SOC38.csv"
# Read the data and assign variable
allState_covid = pd.read_csv(allState_path)
usCovid_covid = pd.read_csv(usCovid_path)
consumer_sentiment = pd.read_csv(conSent_path)

# %%
# Display to Analyze and clean up dataframe for the US
usCovid_covid
# Out:
#            date     death  deathIncrease  inIcuCumulative  inIcuCurrently  \
# 0    2020-12-11  287058.0           2749          33237.0         21010.0
# 1    2020-12-10  284309.0           3115          32919.0         21023.0
# 2    2020-12-09  281194.0           3170          32720.0         20906.0
# 3    2020-12-08  278024.0           2697          32406.0         20483.0
# 4    2020-12-07  275327.0           1297          32120.0         20098.0
# ..          ...       ...            ...              ...             ...
# 320  2020-01-26       NaN              0              NaN             NaN
# 321  2020-01-25       NaN              0              NaN             NaN
# 322  2020-01-24       NaN              0              NaN             NaN
# 323  2020-01-23       NaN              0              NaN             NaN
# 324  2020-01-22       NaN              0              NaN             NaN
#
#      hospitalizedIncrease  hospitalizedCurrently  hospitalizedCumulative  \
# 0                    5444               108108.0                608998.0
# 1                    4335               107276.0                603554.0
# 2                    5424               106705.0                599219.0
# 3                    4309               104623.0                593795.0
# 4                    3614               102148.0                589486.0
# ..                    ...                    ...                     ...
# 320                     0                    NaN                     NaN
# 321                     0                    NaN                     NaN
# 322                     0                    NaN                     NaN
# 323                     0                    NaN                     NaN
# 324                     0                    NaN                     NaN
#
#       negative  negativeIncrease  onVentilatorCumulative  \
# 0    168637806           1449905                  3424.0
# 1    167187901           1339749                  3394.0
# 2    165848152           1276606                  3376.0
# 3    164571546           1192820                  3359.0
# 4    163378726           1386381                  3328.0
# ..         ...               ...                     ...
# 320          0                 0                     NaN
# 321          0                 0                     NaN
# 322          0                 0                     NaN
# 323          0                 0                     NaN
# 324          0                 0                     NaN
#
#      onVentilatorCurrently  positive  positiveIncrease  recovered  states  \
# 0                   7489.0  15592946            232105  6135314.0      56
# 1                   7442.0  15360841            215669  5985047.0      56
# 2                   7624.0  15145172            211020  5891885.0      56
# 3                   7245.0  14934152            215335  5788509.0      56
# 4                   7073.0  14718817            180219  5714557.0      56
# ..                     ...       ...               ...        ...     ...
# 320                    NaN         0                 0        NaN       2
# 321                    NaN         0                 0        NaN       2
# 322                    NaN         0                 0        NaN       2
# 323                    NaN         0                 0        NaN       2
# 324                    NaN         0                 0        NaN       2
#
#      totalTestResults  totalTestResultsIncrease
# 0           215110717                   2094901
# 1           213015816                   1954686
# 2           211061130                   1822067
# 3           209239063                   1628432
# 4           207610631                   1772911
# ..                ...                       ...
# 320                 2                         0
# 321                 2                         0
# 322                 2                         0
# 323                 2                         1
# 324                 1                         0
#
# [325 rows x 18 columns]

# %%
# Make new data frame containing only two columns
usCovid_df = usCovid_covid.loc[:,['date', 'positive']]
usCovid_df
# Out:
#            date  positive
# 0    2020-12-11  15592946
# 1    2020-12-10  15360841
# 2    2020-12-09  15145172
# 3    2020-12-08  14934152
# 4    2020-12-07  14718817
# ..          ...       ...
# 320  2020-01-26         0
# 321  2020-01-25         0
# 322  2020-01-24         0
# 323  2020-01-23         0
# 324  2020-01-22         0
#
# [325 rows x 2 columns]

# %%
#Sort data frame by date so that numbers of positive cases will be smaller on top
cov = usCovid_df.sort_values(by=['date'])
cov.head(20)
# Out:
#            date  positive
# 324  2020-01-22         0
# 323  2020-01-23         0
# 322  2020-01-24         0
# 321  2020-01-25         0
# 320  2020-01-26         0
# 319  2020-01-27         0
# 318  2020-01-28         0
# 317  2020-01-29         0
# 316  2020-01-30         0
# 315  2020-01-31         0
# 314  2020-02-01         0
# 313  2020-02-02         0
# 312  2020-02-03         0
# 311  2020-02-04         0
# 310  2020-02-05         0
# 309  2020-02-06         0
# 308  2020-02-07         0
# 307  2020-02-08         0
# 306  2020-02-09         0
# 305  2020-02-10         0

# %%
# Set x axis 
x_axis = np.arange(len(usCovid_df))

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
f = plt.figure(figsize=(25,10))
ax = f.add_subplot(111)
# Combine line plot and bar plot to one plot
plt.plot(x_axis, cov['positive'])
plt.bar(x_axis, cov['positive'], color = 'r', alpha = 0.50,align = 'edge')
# y-axis on the right side
ax.yaxis.tick_right()
#plt.xticks(tick_locations)
ax.set_xticks([0,11,40,70,101,131,161,192,223,253,284,311])
ax.set_xticklabels(["Jan 20'","Feb 20'", "Mar 20'", "Apr 20'", "May 20'", "Jun 20'",
                   "Jul 20'", "Aug 20'", "Sept 20'","Oct 20'", " Nov 20'", "Dec 20'"],fontsize = 12)
plt.xlim(0,324.5)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

plt.title("US National History of COVID Positive Cases",fontsize = 20)
plt.xlabel('Year 2020',fontsize = 20)
#plt.ylabel("Number of Postive Cases")
ax.yaxis.set_label_position('right')

#Historical Markers
ax.set_ylabel('Number of Postive Casees', fontsize = 20)
ax.annotate('07/13 More than 5 Million Americans Lose Health Insurance', xy=(173, 3000000), xytext=(130, 7000000),
            fontsize = 15, arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('03/13 National Emergency Declared', xy=(52, 100000), xytext=(70, 9000000),
            fontsize = 15, arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('03/27 Stimulus Bill Signed', xy=(64, 10000), xytext=(80, 4500000),
            fontsize = 15, arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('03/26 U.S. led World in Positive Cases', xy=(63, 10000), xytext=(80, 8000000),
            fontsize = 15, arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('01/31 Trump Restricts Travel from China', xy=(10, 10000), xytext=(10, 10000000),
            fontsize = 15, arrowprops=dict(facecolor='black', shrink=0.05))


# Save image in directory COVID_data
plt.savefig('covid_us_barplot.png')
plt.show()

# %% [markdown]
# # # plot line chart for US Cov

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
f = plt.figure(figsize=(25,10))
ax = f.add_subplot(111)

plt.plot(x_axis, cov['positive'])
#plt.xticks(tick_locations)
ax.set_xticks([0,11,40,70,101,131,161,192,223,253,284,311])
ax.set_xticklabels(["Jan 20'"," Feb 20'", "Mar 20'", "Apr 20'", "May 20'", "Jun 20'",
                   "Jul 20'", "Aug 20'", "Sept 20'","Oct 20'", " Nov 20'", "Dec 20'"],fontsize = 12)
# y-axis on the right side
ax.yaxis.tick_right()
plt.xlim(0,324.5)
plt.ylim(-1,17000000)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

plt.title("US National History of COVID Positive Cases",fontsize = 20)
plt.xlabel('Year 2020',fontsize = 20)
#plt.ylabel("Number of Postive Cases")
ax.yaxis.set_label_position('right')
ax.set_ylabel('Number of Postive Casees', fontsize = 20)

#Historical Markers
ax.set_ylabel('Number of Postive Casees', fontsize = 20)
ax.annotate('07/13 More than 5 Million Americans Lose Health Insurance', xy=(173, 3000000), xytext=(130, 7000000),
            fontsize = 15, arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('03/13 National Emergency Declared', xy=(52, 100000), xytext=(7, 4000000),
            fontsize = 15, arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('03/27 Stimulus Bill Signed', xy=(64, 10000), xytext=(80, 4500000),
            fontsize = 15, arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('03/26 U.S. led World in Positive Cases', xy=(63, 10000), xytext=(80, 8000000),
            fontsize = 15, arrowprops=dict(facecolor='black', shrink=0.05))

# Save image in directory COVID_data
plt.savefig('covid_us_lineplot.png')
plt.show()

# %%
# Display to Analyze and clean up dataframe for all states
allState_covid
# Out:
#              date          state  fips   cases  deaths
# 0      2020-01-21     Washington    53       1       0
# 1      2020-01-22     Washington    53       1       0
# 2      2020-01-23     Washington    53       1       0
# 3      2020-01-24       Illinois    17       1       0
# 4      2020-01-24     Washington    53       1       0
# ...           ...            ...   ...     ...     ...
# 15739  2020-12-13       Virginia    51  281909    4411
# 15740  2020-12-13     Washington    53  209385    3045
# 15741  2020-12-13  West Virginia    54   63217     968
# 15742  2020-12-13      Wisconsin    55  468956    4344
# 15743  2020-12-13        Wyoming    56   39360     321
#
# [15744 rows x 5 columns]

# %%
# Clean dataframe and drop rows with Nan
allState_covid_df = allState_covid.loc[:,['state','cases']]
allState_covid_df
# Out:
#                state   cases
# 0         Washington       1
# 1         Washington       1
# 2         Washington       1
# 3           Illinois       1
# 4         Washington       1
# ...              ...     ...
# 15739       Virginia  281909
# 15740     Washington  209385
# 15741  West Virginia   63217
# 15742      Wisconsin  468956
# 15743        Wyoming   39360
#
# [15744 rows x 2 columns]

# %%
# make dataframe out of grouped state and column death

state_df = allState_covid_df.groupby('state')

sum_state = state_df['cases'].sum()
state_drop = sum_state.drop(['Guam','Puerto Rico','Virgin Islands','Northern Mariana Islands','District of Columbia'])

sumCases_perState = state_drop.reset_index()
sumCases_perState
# Out:
#              state      cases
# 0          Alabama   26285286
# 1           Alaska    2058274
# 2          Arizona   38661186
# 3         Arkansas   14692185
# 4       California  139306788
# 5         Colorado   17761802
# 6      Connecticut   14167996
# 7         Delaware    4217379
# 8          Florida  116041547
# 9          Georgia   51719092
# 10          Hawaii    1760554
# 11           Idaho    8221259
# 12        Illinois   65661970
# 13         Indiana   27379845
# 14            Iowa   18404655
# 15          Kansas   12183760
# 16        Kentucky   14306247
# 17       Louisiana   29876039
# 18           Maine    1188420
# 19        Maryland   24525017
# 20   Massachusetts   31413991
# 21        Michigan   33070007
# 22       Minnesota   22664984
# 23     Mississippi   16927459
# 24        Missouri   24388843
# 25         Montana    3604477
# 26        Nebraska   10275999
# 27          Nevada   14535050
# 28   New Hampshire    2041386
# 29      New Jersey   49408545
# 30      New Mexico    7200200
# 31        New York  110463832
# 32  North Carolina   37456806
# 33    North Dakota    5053620
# 34            Ohio   33408781
# 35        Oklahoma   15725466
# 36          Oregon    6455333
# 37    Pennsylvania   36879761
# 38    Rhode Island    5900741
# 39  South Carolina   24274413
# 40    South Dakota    5500276
# 41       Tennessee   34500516
# 42           Texas  130785938
# 43            Utah   15396649
# 44         Vermont     441699
# 45        Virginia   27149545
# 46      Washington   17754551
# 47   West Virginia    3327947
# 48       Wisconsin   29046126
# 49         Wyoming    1831193

# %%
# Create a bar plot that shows covid cases per state
# fig size
f = plt.figure(figsize=(25,10))
ax = f.add_subplot(111)
# make a list for state and cases
x_axis = sumCases_perState['state'].tolist()
y_axis = sumCases_perState['cases'].tolist()

# format numbers to avoid scientific notation
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# rotate text vertically
plt.xticks(rotation = 'vertical')
# plot bar graph
plt.bar(x_axis,y_axis, align = 'center', width = .75, color = "red", alpha = 0.75)
# Labels
plt.xlim(-0.5,len(x_axis)-.5)
plt.ylim(0, 150000000)
plt.ylabel('Number of Positive Cases',fontsize = 20)
plt.title("2020 Total Number of Positive Cases Per State" ,fontsize = 20)
plt.xlabel('U.S. States',fontsize = 20)
# save to file
plt.savefig('covid_st_barplot.png')

plt.show()

# %%
# Covid line plot cases per state 
#define x and y axis
x_axis = sumCases_perState['state'].tolist()
y_axis = sumCases_perState['cases'].tolist()
f = plt.figure(figsize=(25,10))
ax = f.add_subplot(111)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.xticks(rotation = 'vertical')

plt.plot(x_axis,y_axis,c='red',alpha = 0.75)

plt.xlim(0,len(x_axis)-0.8)
plt.ylim(0, 150000000)
plt.ylabel('Number of Positive Cases',fontsize = 20)
plt.title("2020 Number of Positive Cases Per State" ,fontsize = 20)
plt.xlabel('U.S. States',fontsize = 20)

plt.savefig('covid_st_plot.png')

plt.show()

# %%
# Display consumer_sentiment dataframe
consumer_sentiment
# Out:
#            Date  Good Time<br>Prices are Low  \
# 0    2020-10-31                         35.0
# 1    2020-09-30                         37.0
# 2    2020-08-31                         40.0
# 3    2020-07-31                         43.0
# 4    2020-06-30                         49.0
# ..          ...                          ...
# 508  1978-06-30                          7.0
# 509  1978-05-31                          6.0
# 510  1978-04-30                          7.0
# 511  1978-03-31                         12.0
# 512  1978-02-28                         10.0
#
#      Good Time<br>Prices will increase  Good Time<br>Interest rates low  \
# 0                                  1.0                             24.0
# 1                                  3.0                             25.0
# 2                                  1.0                             25.0
# 3                                  1.0                             22.0
# 4                                  2.0                             28.0
# ..                                 ...                              ...
# 508                               39.0                              1.0
# 509                               33.0                              1.0
# 510                               36.0                              1.0
# 511                               34.0                              0.0
# 512                               25.0                              0.0
#
#      Good Time<br>Rising interest rates  Good Time<br>Times good  \
# 0                                   0.0                      7.0
# 1                                   0.0                      7.0
# 2                                   0.0                      5.0
# 3                                   0.0                      4.0
# 4                                   0.0                      4.0
# ..                                  ...                      ...
# 508                                 1.0                      4.0
# 509                                 1.0                      3.0
# 510                                 1.0                      3.0
# 511                                 2.0                      2.0
# 512                                 1.0                      1.0
#
#      Good Time<br>Fuel Efficiency  Bad Time<br>Prices High  \
# 0                             0.0                     12.0
# 1                             1.0                     11.0
# 2                             0.0                     10.0
# 3                             0.0                     10.0
# 4                             0.0                      6.0
# ..                            ...                      ...
# 508                           3.0                     24.0
# 509                           3.0                     23.0
# 510                           3.0                     22.0
# 511                           3.0                     20.0
# 512                           3.0                     22.0
#
#      Bad Time<br>Interest rates high  Bad Time<br>Can't Afford  \
# 0                                4.0                      14.0
# 1                                2.0                      10.0
# 2                                5.0                      12.0
# 3                                6.0                      12.0
# 4                                4.0                      10.0
# ..                               ...                       ...
# 508                              4.0                       1.0
# 509                              3.0                       2.0
# 510                              2.0                       3.0
# 511                              2.0                       4.0
# 512                              1.0                       2.0
#
#      Bad Time<br>Uncertain Future  Bad Time<br>Gas Prices  \
# 0                            13.0                     0.0
# 1                            14.0                     0.0
# 2                            18.0                     0.0
# 3                            18.0                     0.0
# 4                            15.0                     0.0
# ..                            ...                     ...
# 508                           1.0                     1.0
# 509                           0.0                     1.0
# 510                           0.0                     2.0
# 511                           1.0                     1.0
# 512                           2.0                     3.0
#
#      Bad Time<br>Poor Selection  Relative: prices  Relative: rates
# 0                           1.0              23.0             20.0
# 1                           1.0              26.0             23.0
# 2                           2.0              30.0             20.0
# 3                           1.0              33.0             16.0
# 4                           1.0              43.0             24.0
# ..                          ...               ...              ...
# 508                        11.0             -17.0             -3.0
# 509                         8.0             -17.0             -2.0
# 510                        10.0             -15.0             -1.0
# 511                         8.0              -8.0             -2.0
# 512                         7.0             -12.0             -1.0
#
# [513 rows x 15 columns]

# %%
# Creating a dataframe for consumer sentiment with renaming columns
consumer_sentiment_df = consumer_sentiment.loc[:,['Date', "Good Time<br>Times good","Good Time<br>Interest rates low"]]
consumer_sentiment_df.rename(columns = {"Good Time<br>Times good":"Good Times","Good Time<br>Interest rates low":
                                       "Good Time-Interest rates low"}, inplace = True) 
consumer_sentiment_df
# Out:
#            Date  Good Times  Good Time-Interest rates low
# 0    2020-10-31         7.0                          24.0
# 1    2020-09-30         7.0                          25.0
# 2    2020-08-31         5.0                          25.0
# 3    2020-07-31         4.0                          22.0
# 4    2020-06-30         4.0                          28.0
# ..          ...         ...                           ...
# 508  1978-06-30         4.0                           1.0
# 509  1978-05-31         3.0                           1.0
# 510  1978-04-30         3.0                           1.0
# 511  1978-03-31         2.0                           0.0
# 512  1978-02-28         1.0                           0.0
#
# [513 rows x 3 columns]

# %%
consumer_sentiment_df['Date'] = pd.to_datetime(consumer_sentiment_df['Date'])
consumer_sentiment_df
# Out:
#           Date  Good Times  Good Time-Interest rates low
# 0   2020-10-31         7.0                          24.0
# 1   2020-09-30         7.0                          25.0
# 2   2020-08-31         5.0                          25.0
# 3   2020-07-31         4.0                          22.0
# 4   2020-06-30         4.0                          28.0
# ..         ...         ...                           ...
# 508 1978-06-30         4.0                           1.0
# 509 1978-05-31         3.0                           1.0
# 510 1978-04-30         3.0                           1.0
# 511 1978-03-31         2.0                           0.0
# 512 1978-02-28         1.0                           0.0
#
# [513 rows x 3 columns]

# %%
start_date = '2019-12-31'
end_date = '2020-10-31'
mask = (consumer_sentiment_df['Date'] > start_date) & (consumer_sentiment_df['Date'] <= end_date)

# %%
# Creating a dataframe for just the available data for the start date to end dates of 2020
Con_Sum_df = consumer_sentiment_df.loc[mask]
Con_Sum_df
# Out:
#         Date  Good Times  Good Time-Interest rates low
# 0 2020-10-31         7.0                          24.0
# 1 2020-09-30         7.0                          25.0
# 2 2020-08-31         5.0                          25.0
# 3 2020-07-31         4.0                          22.0
# 4 2020-06-30         4.0                          28.0
# 5 2020-05-31         3.0                          25.0
# 6 2020-04-30         5.0                          19.0
# 7 2020-03-31        14.0                          22.0
# 8 2020-02-29        18.0                          19.0
# 9 2020-01-31        18.0                          18.0

# %%
Con_Sum_df = pd.DataFrame([["2020-01", 18.0,18.0], ["2020-02", 18,19], ["2020-03", 14.0,22.0], ["2020-04",5.0,19.0],
                      ["2020-05", 3.0,25.0], ["2020-6", 4.0,28.0], ["2020-07", 4.0,22.0], ["2020-08",5.0,25.0],
                      ['2020-09',7.0,25.0], ['2020-10',7.0,24.0]], 
                   columns=["Date", "Good Times", "Good Times-Interest rates low"])
Con_Sum_df
# Out:
#       Date  Good Times  Good Times-Interest rates low
# 0  2020-01        18.0                           18.0
# 1  2020-02        18.0                           19.0
# 2  2020-03        14.0                           22.0
# 3  2020-04         5.0                           19.0
# 4  2020-05         3.0                           25.0
# 5   2020-6         4.0                           28.0
# 6  2020-07         4.0                           22.0
# 7  2020-08         5.0                           25.0
# 8  2020-09         7.0                           25.0
# 9  2020-10         7.0                           24.0

# %%
usCovid_df = pd.DataFrame([["2020-01", 0], ["2020-02", 18], ["2020-03", 1217580], ["2020-04", 19644427],
                      ["2020-05", 45281131], ["2020-6", 64585035], ["2020-07", 110430409], ["2020-08",164902258],
                      ['2020-09',197248843], ['2020-10',248547877], ['2020-11',332259071],
                      ["2020-12",159951693]], 
                   columns=["date", "positive"])
usCovid_df = usCovid_df.rename(columns={"date":"Date","positive":"Positive"})
usCovid_df
# Out:
#        Date   Positive
# 0   2020-01          0
# 1   2020-02         18
# 2   2020-03    1217580
# 3   2020-04   19644427
# 4   2020-05   45281131
# 5    2020-6   64585035
# 6   2020-07  110430409
# 7   2020-08  164902258
# 8   2020-09  197248843
# 9   2020-10  248547877
# 10  2020-11  332259071
# 11  2020-12  159951693

# %%
casesVsentiment = pd.merge(Con_Sum_df,usCovid_df)
casesVsentiment
# Out:
#       Date  Good Times  Good Times-Interest rates low   Positive
# 0  2020-01        18.0                           18.0          0
# 1  2020-02        18.0                           19.0         18
# 2  2020-03        14.0                           22.0    1217580
# 3  2020-04         5.0                           19.0   19644427
# 4  2020-05         3.0                           25.0   45281131
# 5   2020-6         4.0                           28.0   64585035
# 6  2020-07         4.0                           22.0  110430409
# 7  2020-08         5.0                           25.0  164902258
# 8  2020-09         7.0                           25.0  197248843
# 9  2020-10         7.0                           24.0  248547877

# %%
from matplotlib.legend_handler import HandlerLine2D

x_axis = casesVsentiment['Date']
x_axis1 = casesVsentiment['Date']
x_axis2 = casesVsentiment['Date']
y_axis = casesVsentiment["Good Times"]

y_axis1 = casesVsentiment["Good Times-Interest rates low"]

y_axis2 = casesVsentiment["Positive"]
#ax = f.add_subplot(111)
#ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#plt.xticks(rotation = 'vertical')
# fig size
f=plt.figure(figsize=(25,10))
ax = f.add_subplot(111)
line1, = ax.plot(x_axis,y_axis,c='orange',alpha = 0.75, label = "Good Time")

line2, = plt.plot(x_axis1,y_axis1,c='blue',alpha = 0.75, label = "Good Times-Interest rates low")
first_legend = plt.legend(handles=[line1,line2,line3], loc='lower right')
plt.ylabel('Consumer Senitiment',fontsize = 20)
ax2 = ax.twinx()
ax2.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
line3, = ax2.plot(x_axis2,y_axis2,c='red',alpha = 0.75, label = "Positive Covid Cases")
ax2.set_ylabel('Number of Postive Casees', fontsize = 20)

#plt.xlim(-2,len(x_axis1))
#plt.ylim(0, 30)

plt.title("Opinions for Buying Conditions for Vehicles" ,fontsize = 20)


# x coordinates for the lines
xcoords = [.9838,2.4193, 2.9,6.4193]
# colors for the lines
colors = ['k','r','b','k']

for xc,c in zip(xcoords,colors):
    plt.axvline(x=xc, label='line at x = {}'.format(xc), c=c)

plt.show()
