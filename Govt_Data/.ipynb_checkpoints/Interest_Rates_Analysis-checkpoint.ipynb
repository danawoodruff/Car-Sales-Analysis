# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# data files
interest = "Interest_rates.csv"

# Read the data 
interest_df = pd.read_csv(interest)

# %%
interest_df
# Out:
#            DATE  4wk BANK DISCOUNT  8 wk BANK DISCOUNT  13 wk BANK DISCOUNT  \
# 0      1/2/2020               1.50                1.52                 1.51
# 1      1/3/2020               1.49                1.52                 1.49
# 2      1/6/2020               1.51                1.51                 1.53
# 3      1/7/2020               1.49                1.50                 1.51
# 4      1/8/2020               1.47                1.50                 1.51
# ..          ...                ...                 ...                  ...
# 482  12/24/2019               1.52                1.55                 1.55
# 483  12/26/2019               1.56                1.57                 1.55
# 484  12/27/2019               1.53                1.53                 1.54
# 485  12/30/2019               1.48                1.50                 1.54
# 486  12/31/2019               1.45                1.48                 1.52
#
#      26 wk BANK DISCOUNT  52 wk BANK DISCOUNT
# 0                   1.53                 1.52
# 1                   1.51                 1.51
# 2                   1.52                 1.50
# 3                   1.52                 1.49
# 4                   1.52                 1.51
# ..                   ...                  ...
# 482                 1.57                 1.49
# 483                 1.57                 1.49
# 484                 1.55                 1.47
# 485                 1.56                 1.53
# 486                 1.56                 1.55
#
# [487 rows x 6 columns]

# %%
interest_df['DATE'] = pd.to_datetime(interest_df['DATE'])
interest_df
# Out:
#           DATE  4wk BANK DISCOUNT  8 wk BANK DISCOUNT  13 wk BANK DISCOUNT  \
# 0   2020-01-02               1.50                1.52                 1.51
# 1   2020-01-03               1.49                1.52                 1.49
# 2   2020-01-06               1.51                1.51                 1.53
# 3   2020-01-07               1.49                1.50                 1.51
# 4   2020-01-08               1.47                1.50                 1.51
# ..         ...                ...                 ...                  ...
# 482 2019-12-24               1.52                1.55                 1.55
# 483 2019-12-26               1.56                1.57                 1.55
# 484 2019-12-27               1.53                1.53                 1.54
# 485 2019-12-30               1.48                1.50                 1.54
# 486 2019-12-31               1.45                1.48                 1.52
#
#      26 wk BANK DISCOUNT  52 wk BANK DISCOUNT
# 0                   1.53                 1.52
# 1                   1.51                 1.51
# 2                   1.52                 1.50
# 3                   1.52                 1.49
# 4                   1.52                 1.51
# ..                   ...                  ...
# 482                 1.57                 1.49
# 483                 1.57                 1.49
# 484                 1.55                 1.47
# 485                 1.56                 1.53
# 486                 1.56                 1.55
#
# [487 rows x 6 columns]

# %%
interest_df = interest_df[interest_df['DATE'] <= '10/1/2020']
interest_df
# Out:
#           DATE  4wk BANK DISCOUNT  8 wk BANK DISCOUNT  13 wk BANK DISCOUNT  \
# 0   2020-01-02               1.50                1.52                 1.51
# 1   2020-01-03               1.49                1.52                 1.49
# 2   2020-01-06               1.51                1.51                 1.53
# 3   2020-01-07               1.49                1.50                 1.51
# 4   2020-01-08               1.47                1.50                 1.51
# ..         ...                ...                 ...                  ...
# 482 2019-12-24               1.52                1.55                 1.55
# 483 2019-12-26               1.56                1.57                 1.55
# 484 2019-12-27               1.53                1.53                 1.54
# 485 2019-12-30               1.48                1.50                 1.54
# 486 2019-12-31               1.45                1.48                 1.52
#
#      26 wk BANK DISCOUNT  52 wk BANK DISCOUNT
# 0                   1.53                 1.52
# 1                   1.51                 1.51
# 2                   1.52                 1.50
# 3                   1.52                 1.49
# 4                   1.52                 1.51
# ..                   ...                  ...
# 482                 1.57                 1.49
# 483                 1.57                 1.49
# 484                 1.55                 1.47
# 485                 1.56                 1.53
# 486                 1.56                 1.55
#
# [440 rows x 6 columns]

# %%
#Sort values by date 
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html
interest_sorted = interest_df.sort_values('DATE')
interest_sorted
# Out:
#           DATE  4wk BANK DISCOUNT  8 wk BANK DISCOUNT  13 wk BANK DISCOUNT  \
# 237 2019-01-02               2.36                2.36                 2.37
# 238 2019-01-03               2.38                2.38                 2.36
# 239 2019-01-04               2.36                2.38                 2.37
# 240 2019-01-07               2.38                2.38                 2.41
# 241 2019-01-08               2.36                2.38                 2.41
# ..         ...                ...                 ...                  ...
# 185 2020-09-25               0.08                0.09                 0.10
# 186 2020-09-28               0.09                0.10                 0.11
# 187 2020-09-29               0.07                0.08                 0.09
# 188 2020-09-30               0.08                0.08                 0.10
# 189 2020-10-01               0.09                0.09                 0.09
#
#      26 wk BANK DISCOUNT  52 wk BANK DISCOUNT
# 237                 2.45                 2.52
# 238                 2.41                 2.42
# 239                 2.45                 2.49
# 240                 2.48                 2.50
# 241                 2.48                 2.52
# ..                   ...                  ...
# 185                 0.11                 0.12
# 186                 0.11                 0.12
# 187                 0.11                 0.12
# 188                 0.11                 0.12
# 189                 0.10                 0.12
#
# [440 rows x 6 columns]

# %% [markdown]
# # 52 wk BANK DISCOUNT

# %%
# 52 wk BANK DISCOUNT


# Line chart selection
interest_sorted.plot.line(x='DATE', y='52 wk BANK DISCOUNT', legend = False, rot=60, title="Interest rates",)
#                          marker='s', markerfacecolor='red');

# Sets the y limits
plt.ylim(-0.5, 3)

# Provides labels
plt.xlabel("Date", fontsize=12)
plt.ylabel("Interest rates (%)", fontsize=12)

plt.tick_params(axis='both', direction='out', length=6, width=2, labelcolor = 'black',colors='teal')

# Major grid lines
plt.grid(b=True, which='major', color='lightblue', alpha=0.6, linestyle='dashdot', lw=1.5)

# Minor grid lines
plt.minorticks_on()
plt.grid(b=True, which='minor', color='beige', alpha=0.8, ls='-', lw=1)

# Save the figure as .png
#plt.savefig('Images/Interest Rates.png')

plt.show(block=True)

# %%
#Compare the trend between types of interest rates
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(interest_sorted['DATE'], interest_sorted["52 wk BANK DISCOUNT"], color='tab:blue',)
ax.plot(interest_sorted['DATE'], interest_sorted['26 wk BANK DISCOUNT'], color='tab:orange')
ax.plot(interest_sorted['DATE'], interest_sorted["13 wk BANK DISCOUNT"], color='tab:red')
ax.plot(interest_sorted['DATE'], interest_sorted['8 wk BANK DISCOUNT'], color='tab:green')
ax.plot(interest_sorted['DATE'], interest_sorted['4wk BANK DISCOUNT'], color='tab:blue')
# Provides labels
plt.xlabel("Date", fontsize=12)
plt.ylabel("Interest rates (%)", fontsize=12)

plt.tick_params(axis='both', direction='in', length=6, width=2, labelcolor = 'black',colors='teal')

# Major grid lines
plt.grid(b=True, which='major', color='lightblue', alpha=0.6, linestyle='dashdot', lw=1.5)

# Minor grid lines
plt.minorticks_on()
plt.grid(b=True, which='minor', color='beige', alpha=0.8, ls='-', lw=1)
plt.xticks(rotation=90)
# Save the figure as .png
#plt.savefig('Images/Interest Rates.png')

plt.show(block=True)
